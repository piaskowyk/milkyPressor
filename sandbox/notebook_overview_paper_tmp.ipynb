# %%
from src.signal_generator import SignalGenerator
from src.data_type import Measurement
from src.data_compressor.other import CompressNTHS
from src.data_compressor.other import CompressMinMax
from src.data_compressor.other import CompressPWP
from src.data_compressor.pip import CompressPIP_ED
from src.data_compressor.pip import CompressPIP_PD
from src.data_compressor.pip import CompressPIP_VD
from src.data_compressor.paa import CompressPAA
from src.data_compressor.paa import CompressPAAVI
from src.data_compressor.paa import CompressByChunk
from src.data_compressor.pla import CompressAPCADFT
from src.data_compressor.pla import CompressSTC
from src.data_compressor.pla import CompressHigherDeriveration
from src.metric.similarity_metrics import SimilarityMetric
from src.metric.feature_metrics import FeatureMetric

# %%
signal_generator = SignalGenerator(0, 100).with_peaks(4).with_peaks(3, direction=-1).sin(2, 0.2).noise()
measurements = [Measurement(measurement, index) for index, measurement in enumerate(signal_generator.data)]

# %%
def make_plots(data_compressor, config):
  measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
  data_compressor.set_data(measurements_)
  data_compressor.compress()
  print(data_compressor.get_stats())
  # results = SimilarityMetric().compute_all(measurements_, data_compressor.compressed_data)
  # for key in results:
  #   print(f'{key}: {results[key]}')
  # print("------------------------------------------------------")
  results = FeatureMetric().compute_metrics(measurements_)
  for key in results:
    print(f'{key}: {results[key]}')
  data_compressor.vizualize(True, True, config)

# %%
make_plots(CompressNTHS(), { 'title': 'NTH-item compression', 'dir': 'section2/nths', 'fileName': 'section2_nths' })
# Out:
# {'original_size': 100, 'compressed_size': 51, 'compression_rate': 0.49}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressMinMax(), { 'title': 'MinMax compression', 'dir': 'section2/MinMax', 'fileName': 'section2_MinMax' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPWP(), { 'title': 'PwP compression', 'dir': 'section2/PwP', 'fileName': 'section2_PwP' })
# Out:
# {'original_size': 100, 'compressed_size': 58, 'compression_rate': 0.42}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPIP_ED(), { 'title': 'PIP-ED compression', 'dir': 'section2/PIP-ED', 'fileName': 'section2_PIP-ED' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPIP_PD(), { 'title': 'PIP-PD compression', 'dir': 'section2/PIP-PD', 'fileName': 'section2_PIP-PD' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPIP_VD(), { 'title': 'PIP-VD compression', 'dir': 'section2/PIP-VD', 'fileName': 'section2_PIP-VD' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPAA(), { 'title': 'PAA compression', 'dir': 'section2/PAA', 'fileName': 'section2_PAA' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressPAAVI(), { 'title': 'PAADI compression', 'dir': 'section2/PAADI', 'fileName': 'section2_PAADI' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressByChunk(), { 'title': 'ByChunk compression', 'dir': 'section2/ByChunk', 'fileName': 'section2_ByChunk' })
# Out:
# {'original_size': 100, 'compressed_size': 50, 'compression_rate': 0.5}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressAPCADFT(), { 'title': 'APCADFT compression', 'dir': 'section2/APCADFT', 'fileName': 'section2_APCADFT' })
# Out:
# {'original_size': 100, 'compressed_size': 31, 'compression_rate': 0.69}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressSTC(), { 'title': 'STC compression', 'dir': 'section2/STC', 'fileName': 'section2_STC' })
# Out:
# {'original_size': 100, 'compressed_size': 95, 'compression_rate': 0.05}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995

# %%
make_plots(CompressHigherDeriveration(), { 'title': 'PwHD compression', 'dir': 'section2/PwHD', 'fileName': 'section2_PwHD' })
# Out:
# {'original_size': 100, 'compressed_size': 13, 'compression_rate': 0.87}
# arithmetic_average: 0.01
# standard_derivative: 1.6445174219961058
# function_field: -0.9370471859732407
# min_value: -1.0433595691884447
# max_value: -0.9584423525034891
# min_max_diff: -0.6722724777525416
# value_crossing: 0.1
# positive_value_crossing: 0.05
# negative_value_crossing: 0.05
# peak_count: 0.35
# positive_peak_count: 0.18
# negative_peak_count: 0.17
# median: 0.03526940101111247
# covariance: -3.470400502189424
# corelation_pearson: -0.07310607330812789
# corelation_spearman: 0.9993999399939995
