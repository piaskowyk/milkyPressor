# %%
from src.signal_generator import SignalGenerator
from src.data_type import Measurement
import matplotlib.pyplot as plt
from src.data_compressor.other import CompressNTHS
from src.data_compressor.other import CompressMinMax
from src.data_compressor.other import CompressPWP
from src.data_compressor.pip import CompressPIP_ED
from src.data_compressor.pip import CompressPIP_PD
from src.data_compressor.pip import CompressPIP_VD
from src.data_compressor.paa import CompressPAA
from src.data_compressor.paa import CompressPAAVI
from src.data_compressor.paa import CompressByChunk
from src.data_compressor.pla import CompressAPCADFT
from src.data_compressor.pla import CompressAPCAFFT
from src.data_compressor.pla import CompressSTC
from src.data_compressor.pla import CompressHigherDeriveration
from src.measurement_provider import MeasurementProvider

# %%
# signal_generator = SignalGenerator(0, 100).with_peaks(3).with_peaks(3, direction=-1).sin(0.2, 0.2)
# measurements = [Measurement(measurement, index * 100) for index, measurement in enumerate(signal_generator.data)]
measurements = MeasurementProvider().json_to_measurements('airlines.json')[:1000]

# %%
data_compressor = CompressNTHS()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 184, 'compression_rate': 0.4972677595628415}

# %%
data_compressor = CompressMinMax()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 184, 'compression_rate': 0.4972677595628415}

# %%
data_compressor = CompressPWP()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 193, 'compression_rate': 0.4726775956284153}

# %%
data_compressor = CompressPIP_ED()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 183, 'compression_rate': 0.5}

# %%
data_compressor = CompressPIP_PD()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 183, 'compression_rate': 0.5}

# %%
data_compressor = CompressPIP_VD()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 183, 'compression_rate': 0.5}

# %%
data_compressor = CompressPAA()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 20, 'compression_rate': 0.9453551912568307}

# %%
data_compressor = CompressPAAVI()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 20, 'compression_rate': 0.9453551912568307}

# %%
data_compressor = CompressByChunk()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 73, 'compression_rate': 0.8005464480874317}

# %%
data_compressor = CompressAPCADFT()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 119, 'compression_rate': 0.674863387978142}

# %%
data_compressor = CompressAPCAFFT()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 123, 'compression_rate': 0.6639344262295082}

# %%
data_compressor = CompressSTC()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 338, 'compression_rate': 0.07650273224043716}

# %%
data_compressor = CompressHigherDeriveration()
measurements_ = [Measurement(measurement.value, measurement.timestamp) for measurement in measurements]
data_compressor.set_data(measurements_)
data_compressor.compress()
print(data_compressor.get_stats())
data_compressor.vizualize(True, True)
# Out:
# {'original_size': 366, 'compressed_size': 365, 'compression_rate': 0.00273224043715847}
